# %% [markdown]
# # Deep Learning on Your Own Computer
# By. Afif A. Iskandar

# %% [markdown]
# ## Membuat klasifier citra untuk kasus pembalap MotoGP

# %% [markdown]
# ## Melatih CNN

# %%
# import library yang dibutuhkan
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from neural_net.smallervggnet import SmallerVGGNet
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import os
import pickle
import matplotlib
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline

# %%
def list_images(basePath, contains=None):
    # return the set of files that are valid
    return list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"), contains=contains)

def list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"), contains=None):
    # loop over the directory structure
    for (rootDir, dirNames, filenames) in os.walk(basePath):
        # loop over the filenames in the current directory
        for filename in filenames:
            # if the contains string is not none and the filename does not contain
            # the supplied string, then ignore the file
            if contains is not None and filename.find(contains) == -1:
                continue

            # determine the file extension of the current file
            ext = filename[filename.rfind("."):].lower()

            # check to see if the file is an image and should be processed
            if ext.endswith(validExts):
                # construct the path to the image and yield it
                imagePath = os.path.join(rootDir, filename).replace(" ", "\\ ")
                yield imagePath

# %%
# Definisikan path dataset dan tempat menyimpan model
dataset = 'dataset/'
model_path = 'gprider.pkl'
labelbin = 'lb.pickle'

# %%
#  hyperparameter
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
IMAGE_DIMS = (96, 96, 3)

# %%
# inisialisasi list data dan label
data = []
labels = []

# load gambar dan acak untuk train + test
imagePaths = sorted(list(list_images(dataset)))
random.seed(42)
random.shuffle(imagePaths)

# %%
# loop pada dataset
for imagePath in imagePaths:
    image = load_img(imagePath, target_size=(IMAGE_DIMS[1], IMAGE_DIMS[0]))
    image = img_to_array(image)
    data.append(image)

    # ekstrak label
    label = imagePath.split(os.path.sep)[-2]
    labels.append(label)

# %%
# Normalisasi data
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
print("[INFO] data matriks: {:2f}MB".format(
    data.nbytes/ (1024 * 1000.0)))
# Out:
# [INFO] data matriks: 102.600000MB

# %%
# binarisasi label
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
# train-test-split
(trainX, testX, trainY, testY) = train_test_split(data,
    labels, test_size=0.2, random_state=42)

# %%
# konstruksi ImageGenerator
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
    horizontal_flip=True, fill_mode="nearest")

# %%
# inisialisasi model
print("[INFO] Mengcompile Jaringan")
model = SmallerVGGNet.build(width=IMAGE_DIMS[1], 
    height=IMAGE_DIMS[0], depth=IMAGE_DIMS[2], 
    classes=len(lb.classes_))
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt,
    metrics=["accuracy"])
# Out:
# [INFO] Mengcompile Jaringan

# %%
# latih jaringan
print("[INFO] Melatih Jaringan")
H = model.fit_generator(
    aug.flow(trainX, trainY, batch_size=BS),
    validation_data=(testX, testY),
    steps_per_epoch=len(trainX) // BS,
    epochs=EPOCHS, verbose=1)
# Out:
# [INFO] Melatih Jaringan
# Epoch 1/100
# 11/11 [==============================] - 73s 7s/step - loss: 2.6597 - acc: 0.2716 - val_loss: 5.2654 - val_acc: 0.2737
# Epoch 2/100
# 11/11 [==============================] - 69s 6s/step - loss: 1.8033 - acc: 0.4773 - val_loss: 3.6429 - val_acc: 0.5263
# Epoch 3/100
# 11/11 [==============================] - 69s 6s/step - loss: 1.5228 - acc: 0.5161 - val_loss: 4.2402 - val_acc: 0.4632
# Epoch 4/100
# 11/11 [==============================] - 68s 6s/step - loss: 1.2049 - acc: 0.5988 - val_loss: 2.8082 - val_acc: 0.4526
# Epoch 5/100
# 11/11 [==============================] - 70s 6s/step - loss: 0.9555 - acc: 0.6790 - val_loss: 1.8161 - val_acc: 0.4842
# Epoch 6/100
# 11/11 [==============================] - 68s 6s/step - loss: 0.8697 - acc: 0.6559 - val_loss: 2.5281 - val_acc: 0.5053
# Epoch 7/100
# 11/11 [==============================] - 68s 6s/step - loss: 1.0053 - acc: 0.6330 - val_loss: 3.5066 - val_acc: 0.4211
# Epoch 8/100
# 11/11 [==============================] - 69s 6s/step - loss: 0
# Epoch 86/100
# 11/11 [==============================] - 85s 8s/step - loss: 0.1900 - acc: 0.9225 - val_loss: 1.1393 - val_acc: 0.6632
# Epoch 87/100
# 11/11 [==============================] - 86s 8s/step - loss: 0.2520 - acc: 0.8997 - val_loss: 1.1340 - val_acc: 0.6737
# Epoch 88/100
# 11/11 [==============================] - 85s 8s/step - loss: 0.1900 - acc: 0.9205 - val_loss: 4.1978 - val_acc: 0.4421
# Epoch 89/100
# 11/11 [==============================] - 85s 8s/step - loss: 0.1866 - acc: 0.9164 - val_loss: 2.2133 - val_acc: 0.5579
# Epoch 90/100
# 11/11 [==============================] - 84s 8s/step - loss: 0.2146 - acc: 0.9241 - val_loss: 1.4021 - val_acc: 0.6632
# Epoch 91/100
# 11/11 [==============================] - 85s 8s/step - loss: 0.1888 - acc: 0.9346 - val_loss: 1.4066 - val_acc: 0.6842
# Epoch 92/100
# 11/11 [==============================] - 84s 8s/step - loss: 0.2211 - acc: 0.9139 - val_loss: 1.9123 - val_acc: 0.5579
# Epoch 93/100
# 11/11 [==============================] - 83s 8s/step - loss: 0.2350 - acc: 0.9034 - val_loss: 0.8634 - val_acc: 0.7684
# Epoch 94/100
# 11/11 [==============================] - 69s 6s/step - loss: 0.2160 - acc: 0.9225 - val_loss: 1.1106 - val_acc: 0.6632
# Epoch 95/100
# 11/11 [==============================] - 70s 6s/step - loss: 0.2038 - acc: 0.9054 - val_loss: 0.9718 - val_acc: 0.6842
# Epoch 96/100
# 11/11 [==============================] - 70s 6s/step - loss: 0.1830 - acc: 0.9253 - val_loss: 1.2215 - val_acc: 0.6737
# Epoch 97/100
# 11/11 [==============================] - 69s 6s/step - loss: 0.1656 - acc: 0.9289 - val_loss: 1.5433 - val_acc: 0.6105
# Epoch 98/100
# 11/11 [==============================] - 69s 6s/step - loss: 0.1753 - acc: 0.9217 - val_loss: 1.2901 - val_acc: 0.6842
# Epoch 99/100
# 11/11 [==============================] - 69s 6s/step - loss: 0.1868 - acc: 0.9342 - val_loss: 1.1407 - val_acc: 0.7368
# Epoch 100/100
# 11/11 [==============================] - 70s 6s/step - loss: 0.1187 - acc: 0.9489 - val_loss: 3.3945 - val_acc: 0.4947

# %%
# menyimpan model
print("[INFO] Menyimpan Model Kedalam Disk")
model.save(model_path)
# Out:
# [INFO] Menyimpan Model Kedalam Disk

# %%
# menyimpan label binary
print("[INFO] Menyimpan Label Binary")
f = open(labelbin, 'wb')
f.write(pickle.dumps(lb))
f.close()
# Out:
# [INFO] Menyimpan Label Binary

# %%
# plot akrasi
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), H.history["loss"],
    label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"],
    label="val_loss")
plt.plot(np.arange(0, N), H.history["acc"],
    label="train_acc")
plt.plot(np.arange(0, N), H.history["val_acc"],
    label="val_acc")
plt.title("Grafik Akurasi dan Loss")
plt.xlabel("Epochs #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %% [markdown]
# ### Prediksi

# %%
# Load Gambar
import matplotlib.image as mpimg
image_test = 'test/vinales.jpg'
image_show = mpimg.imread(image_test)
image = load_img(image_test, target_size=(96, 96))

# %%
plt.imshow(image_show)

# %%
# pra proses
image = np.array(image, dtype="float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# %%
# klasifikasi input
print('[INFO] Mencari Kelas Gambar')
proba = model.predict(image)[0]
idx = np.argmax(proba)
label = lb.classes_[idx]
# Out:
# [INFO] Mencari Kelas Gambar

# %%
# prediksi label + confidence score
label = "{}: {:.2f}%".format(label, proba[idx] * 100)
print(label)
# Out:
# dataset/vinales: 76.87%
