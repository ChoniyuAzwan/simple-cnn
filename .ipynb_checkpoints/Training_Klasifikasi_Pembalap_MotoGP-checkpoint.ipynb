# %% [markdown]
# # Deep Learning on Your Own Computer
# By. Afif A. Iskandar

# %% [markdown]
# ## Membuat klasifier citra untuk kasus pembalap MotoGP

# %% [markdown]
# ## Melatih CNN

# %%
# import library yang dibutuhkan
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from neural_net.smallervggnet import SmallerVGGNet
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import os
import pickle
import matplotlib
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline

# %%
def list_images(basePath, contains=None):
    # return the set of files that are valid
    return list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"), contains=contains)

def list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"), contains=None):
    # loop over the directory structure
    for (rootDir, dirNames, filenames) in os.walk(basePath):
        # loop over the filenames in the current directory
        for filename in filenames:
            # if the contains string is not none and the filename does not contain
            # the supplied string, then ignore the file
            if contains is not None and filename.find(contains) == -1:
                continue

            # determine the file extension of the current file
            ext = filename[filename.rfind("."):].lower()

            # check to see if the file is an image and should be processed
            if ext.endswith(validExts):
                # construct the path to the image and yield it
                imagePath = os.path.join(rootDir, filename).replace(" ", "\\ ")
                yield imagePath

# %%
# Definisikan path dataset dan tempat menyimpan model
dataset = 'dataset/'
model_path = 'gprider.pkl'
labelbin = 'lb.pickle'

# %%
#  hyperparameter
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
IMAGE_DIMS = (96, 96, 3)

# %%
# inisialisasi list data dan label
data = []
labels = []

# load gambar dan acak untuk train + test
imagePaths = sorted(list(list_images(dataset)))
random.seed(42)
random.shuffle(imagePaths)

# %%
# loop pada dataset
for imagePath in imagePaths:
    image = load_img(imagePath, target_size=(IMAGE_DIMS[1], IMAGE_DIMS[0]))
    image = img_to_array(image)
    data.append(image)

    # ekstrak label
    label = imagePath.split(os.path.sep)[-2]
    labels.append(label)

# %%
# Normalisasi data
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
print("[INFO] data matriks: {:2f}MB".format(
    data.nbytes/ (1024 * 1000.0)))
# Out:
# [INFO] data matriks: 102.600000MB

# %%
# binarisasi label
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
# train-test-split
(trainX, testX, trainY, testY) = train_test_split(data,
    labels, test_size=0.2, random_state=42)

# %%
# konstruksi ImageGenerator
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
    horizontal_flip=True, fill_mode="nearest")

# %%
# inisialisasi model
print("[INFO] Mengcompile Jaringan")
model = SmallerVGGNet.build(width=IMAGE_DIMS[1], 
    height=IMAGE_DIMS[0], depth=IMAGE_DIMS[2], 
    classes=len(lb.classes_))
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt,
    metrics=["accuracy"])
# Out:
# [INFO] Mengcompile Jaringan

# %%
# latih jaringan
print("[INFO] Melatih Jaringan")
H = model.fit_generator(
    aug.flow(trainX, trainY, batch_size=BS),
    validation_data=(testX, testY),
    steps_per_epoch=len(trainX) // BS,
    epochs=EPOCHS, verbose=1)
# Out:
# [INFO] Melatih Jaringan
# Epoch 1/50
# 11/11 [==============================] - 76s 7s/step - loss: 2.7085 - acc: 0.3334 - val_loss: 3.5088 - val_acc: 0.2842
# Epoch 2/50
# 11/11 [==============================] - 76s 7s/step - loss: 2.0390 - acc: 0.3891 - val_loss: 4.2477 - val_acc: 0.3158
# Epoch 3/50
# 11/11 [==============================] - 90s 8s/step - loss: 1.8095 - acc: 0.4367 - val_loss: 5.4665 - val_acc: 0.2421
# Epoch 4/50
# 11/11 [==============================] - 75s 7s/step - loss: 1.4573 - acc: 0.4979 - val_loss: 2.2635 - val_acc: 0.4842
# Epoch 5/50
# 11/11 [==============================] - 72s 7s/step - loss: 1.3337 - acc: 0.5142 - val_loss: 2.3604 - val_acc: 0.4842
# Epoch 6/50
# 11/11 [==============================] - 74s 7s/step - loss: 1.1301 - acc: 0.5975 - val_loss: 1.9145 - val_acc: 0.5263
# Epoch 7/50
# 11/11 [==============================] - 71s 6s/step - loss: 0.9549 - acc: 0.6405 - val_loss: 2.1597 - val_acc: 0.4105
# Epoch 8/50
# 11/11 [==============================] - 71s 6s/step - loss: 0.9083 - acc: 0.6449 - val_loss: 1.7447 - val_acc: 0.5474
# Epoch 9/50
# 11/11 [==============================] - 71s 6s/step - loss: 0
# Epoch 34/50
# 11/11 [==============================] - 81s 7s/step - loss: 0.3451 - acc: 0.8684 - val_loss: 2.3655 - val_acc: 0.4842
# Epoch 35/50
# 11/11 [==============================] - 79s 7s/step - loss: 0.3384 - acc: 0.8495 - val_loss: 1.3915 - val_acc: 0.6947
# Epoch 36/50
# 11/11 [==============================] - 76s 7s/step - loss: 0.3457 - acc: 0.8304 - val_loss: 1.0185 - val_acc: 0.6316
# Epoch 37/50
# 11/11 [==============================] - 78s 7s/step - loss: 0.3720 - acc: 0.8592 - val_loss: 5.5135 - val_acc: 0.3474
# Epoch 38/50
# 11/11 [==============================] - 77s 7s/step - loss: 0.3425 - acc: 0.8551 - val_loss: 0.9913 - val_acc: 0.6105
# Epoch 39/50
# 11/11 [==============================] - 80s 7s/step - loss: 0.3447 - acc: 0.8583 - val_loss: 1.0466 - val_acc: 0.6316
# Epoch 40/50
# 11/11 [==============================] - 80s 7s/step - loss: 0.3166 - acc: 0.8778 - val_loss: 1.2331 - val_acc: 0.6526
# Epoch 41/50
# 11/11 [==============================] - 79s 7s/step - loss: 0.3328 - acc: 0.8558 - val_loss: 4.5030 - val_acc: 0.4632
# Epoch 42/50
# 11/11 [==============================] - 74s 7s/step - loss: 0.4072 - acc: 0.8494 - val_loss: 1.6176 - val_acc: 0.5684
# Epoch 43/50
# 11/11 [==============================] - 71s 6s/step - loss: 0.3535 - acc: 0.8686 - val_loss: 1.2534 - val_acc: 0.6737
# Epoch 44/50
# 11/11 [==============================] - 73s 7s/step - loss: 0.3367 - acc: 0.8608 - val_loss: 1.2656 - val_acc: 0.6316
# Epoch 45/50
# 11/11 [==============================] - 71s 6s/step - loss: 0.4127 - acc: 0.8414 - val_loss: 1.4628 - val_acc: 0.6105
# Epoch 46/50
# 11/11 [==============================] - 71s 6s/step - loss: 0.4820 - acc: 0.8025 - val_loss: 2.9941 - val_acc: 0.5684
# Epoch 47/50
# 11/11 [==============================] - 71s 6s/step - loss: 0.3995 - acc: 0.8453 - val_loss: 1.2254 - val_acc: 0.6000
# Epoch 48/50
# 11/11 [==============================] - 74s 7s/step - loss: 0.3162 - acc: 0.8965 - val_loss: 2.9107 - val_acc: 0.4947
# Epoch 49/50
# 11/11 [==============================] - 67s 6s/step - loss: 0.3915 - acc: 0.8709 - val_loss: 1.9507 - val_acc: 0.5789
# Epoch 50/50
# 11/11 [==============================] - 76s 7s/step - loss: 0.3307 - acc: 0.8705 - val_loss: 2.2507 - val_acc: 0.5263

# %%
# menyimpan model
print("[INFO] Menyimpan Model Kedalam Disk")
model.save(model_path)
# Out:
# [INFO] Menyimpan Model Kedalam Disk

# %%
# menyimpan label binary
print("[INFO] Menyimpan Label Binary")
f = open(labelbin, 'wb')
f.write(pickle.dumps(lb))
f.close()
# Out:
# [INFO] Menyimpan Label Binary

# %%
# plot akrasi
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), H.history["loss"],
    label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"],
    label="val_loss")
plt.plot(np.arange(0, N), H.history["acc"],
    label="train_acc")
plt.plot(np.arange(0, N), H.history["val_acc"],
    label="val_acc")
plt.title("Grafik Akurasi dan Loss")
plt.xlabel("Epochs #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %% [markdown]
# ### Prediksi

# %%
# Load Gambar
import matplotlib.image as mpimg
image_test = 'test/rossi.jpg'
image_show = mpimg.imread(image_test)
image = load_img(image_test, target_size=(96, 96))

# %%
plt.imshow(image_show)

# %%
# pra proses
image = np.array(image, dtype="float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# %%
# klasifikasi input
print('[INFO] Mencari Kelas Gambar')
proba = model.predict(image)[0]
idx = np.argmax(proba)
label = lb.classes_[idx]
# Out:
# [INFO] Mencari Kelas Gambar

# %%
# prediksi label + confidence score
label = "{}: {:.2f}%".format(label, proba[idx] * 100)
print(label)
# Out:
# dataset/rossi: 99.89%
